# %% [markdown]
# # Retrieve notebook and CPU tables from Baserow
#
# PH, Feb 2025

# %%
import requests
import pandas as pd

# %% [markdown]
# Baserow API access token (read only access to all tables of the *Computers* project

# %%
BASEROW_ACCESS_TOKEN='3dDIsaSBqeszii1EmBJ5FSKVPSJmDms8'

# %% [markdown]
# Table IDs

# %%
NB_OFFERS_TABLE = '444311'
CPUS_TABLE = '444310'

# %%
def get_baserow_rows(TABLE_ID, TOKEN, page=1, size=100):
    """Read rows of table `TABLE_ID`.
    
    Returns (row count, json 'results' field)

    If API error, returns the json error message.
    """
    params = {
        'page': int(page),
        'size': int(size),
    }
    res = requests.get(
        f'https://api.baserow.io/api/database/rows/table/{TABLE_ID}/?user_field_names=true',
        headers={
            'Authorization': f'Token {TOKEN}'
        },
        params = params
    )
    if res.ok:
        json = res.json()
        row_count = json['count']
        results = json['results']
        if len(results) < row_count:
            print(f'Warning: response got paginated ({len(results)} rows retrieved over a total of {row_count}).')
        return row_count, results
    else:
        print(f'Warning: unsuccessul request (code {res.status_code})!')
        return 0, res.json()

# %% [markdown]
# ## Notebook offers table

# %%
row_count, nb_offers_raw = get_baserow_rows(NB_OFFERS_TABLE, BASEROW_ACCESS_TOKEN)
print(f'Notebook offers table has {row_count} rows')
# print first row
nb_offers_raw[0]
# Out:
# Notebook offers table has 22 rows
# {'id': 70,
#  'order': '0.50000000000000000000',
#  'Offer': 'T470S 256GB Good',
#  'Active': True,
#  'CPU': [{'id': 67,
#    'value': 'Intel Core i5-7300U',
#    'order': '1.33333333333333325932'}],
#  'Condition': {'id': 2750619, 'value': 'Good', 'color': 'darker-blue'},
#  'RAM': '16',
#  'SSD': '256',
#  'Date de création': '2025-02-22',
#  'ITJustGood': 'https://www.itjustgood.com/ultrabook-lenovo-thinkpad-t470s-reconditionne-intel-core-i5-7200u-16go-ddr4-256go-ssd-nvme-thunderbolt-3-windows-10-14-full-hd-tactile-0btd8993.html',
#  'Price': '190',
#  'Screen resolution': {'id': 2750658, 'value': '1920x1080', 'color': 'green'},
#  'Thunderbolt': False,
#  'Series': [{'id': 69,
#    'value': 'ThinkPad T470S',
#    'order': '3.50000000000000000000'}],
#  'CPU Age': [{'id': 67, 'value': '8.1'}],
#  'GB6 Single': [{'id': 67, 'value': '1088'}],
#  'GB6 Multi': [{'id': 67, 'value': '2030'}],
#  'GB6 Single/€': [{'id': 67, 'value': '5.7'}],
#  'GB6 Multi/€': [{'id': 67, 'value': '10.7'}]}

# %%
def simplify_nb_offers(table_raw):
    """simplifies the raw notebook offers JSON"""
    table_simple = []
    for row in table_raw:
        row_simple = {
            'Offer': row['Offer'],
            'Price': float(row['Price']),
            'CPU': row['CPU'][0]['value'],
            'CPU Age': float(row['CPU Age'][0]['value']),
            'RAM': float(row['RAM']),
            'SSD': float(row['SSD']),
            'Condition': row['Condition']['value'],
            'Active': row['Active'],
            'GB6 Single': float(row['GB6 Single'][0]['value']),
            'GB6 Multi': float(row['GB6 Multi'][0]['value']),
            'GB6 Single/€': float(row['GB6 Single/€'][0]['value']),
            'GB6 Multi/€': float(row['GB6 Multi/€'][0]['value']),
        }
        table_simple.append(row_simple)
    nrow = len(table_simple)
    print(f'{nrow} notebook offers simplified')
    return table_simple

# %%
nb_offers = simplify_nb_offers(nb_offers_raw)
pd.DataFrame.from_dict(nb_offers)
# Out:
# 22 notebook offers simplified
#                                Offer  Price                    CPU  CPU Age  \
# 0                   T470S 256GB Good  190.0    Intel Core i5-7300U      8.1
# 1          Latitude 5480 240 GB Good  210.0    Intel Core i5-6200U      9.7
# 2                 Dell Latitude 5400  250.0    Intel Core i5-8365U      5.9
# 3                 Dell Latitude 5400  270.0    Intel Core i5-8365U      5.9
# 4                 Dell Latitude 3400  280.0    Intel Core i5-8365U      5.9
# 5              Lenovo ThinkPad T490S  310.0    Intel Core i5-8365U      5.9
# 6                 Dell Latitude 5410  330.0   Intel Core i5-10310U      4.9
# 7                 Dell Latitude 5410  350.0   Intel Core i5-10310U      4.9
# 8              Lenovo ThinkPad T490S  360.0    Intel Core i5-8365U      5.9
# 9                 Dell Latitude 5420  360.0   Intel Core i5-10310U      4.9
# 10                Dell Latitude 5420  500.0   Intel Core i5-1145G7      4.1
# 11      EliteBook 640 G9 512GB VGood  650.0    Intel Core i5-1245U      3.1
# 12                  T14 G3 1TB VGood  730.0    Intel Core i5-1245U      3.1
# 13                   T14 G1 512 Good  410.0   Intel Core i5-10210U      5.7
# 14                  T14 G1 256 VGood  430.0   Intel Core i5-10210U      5.7
# 15                  T14 G1 512 VGood  470.0   Intel Core i5-10210U      5.7
# 16              T14 G1 AMD 240G Good  510.0  AMD Ryzen 5 PRO 4650U      4.6
# 17             T14 G1 AMD 512GB Good  380.0  AMD Ryzen 5 PRO 4650U      4.6
# 18       EliteBook 845 G8 512GB Good  470.0  AMD Ryzen 5 PRO 5650U      4.0
# 19        ProBook 640 G8 500GB VGood  550.0   Intel Core i5-1145G7      4.1
# 20  EliteBook 745 G5 AMD 256GB VGood  230.0  AMD Ryzen 7 PRO 2700U      7.4
# 21                   T495 500GB Good  380.0  AMD Ryzen 5 PRO 3500U      6.1
#
#      RAM     SSD  Condition  Active  GB6 Single  GB6 Multi  GB6 Single/€  \
# 0   16.0   256.0       Good    True      1088.0     2030.0           5.7
# 1   16.0   240.0       Good    True       916.0     1832.0           4.4
# 2   16.0   240.0       Good    True      1270.0     3167.0           5.1
# 3   16.0   240.0  Very Good    True      1270.0     3167.0           4.7
# 4   16.0   240.0  Very Good    True      1270.0     3167.0           4.5
# 5   16.0   500.0       Good    True      1270.0     3167.0           4.1
# 6   16.0   240.0       Good    True      1297.0     3450.0           3.9
# 7   16.0   240.0       Good    True      1297.0     3450.0           3.7
# 8   16.0   500.0  Very Good    True      1270.0     3167.0           3.5
# 9   16.0   500.0       Good    True      1297.0     3450.0           3.6
# 10  16.0   500.0  Very Good    True      1766.0     4873.0           3.5
# 11  16.0   500.0  Very Good   False      1964.0     6269.0           3.0
# 12  16.0  1000.0  Very Good   False      1964.0     6269.0           2.7
# 13  16.0   512.0       Good    True      1229.0     3088.0           3.0
# 14  16.0   256.0  Very Good    True      1229.0     3088.0           2.9
# 15  16.0   512.0  Very Good    True      1229.0     3088.0           2.6
# 16  16.0   240.0       Good   False      1421.0     4591.0           2.8
# 17  16.0   512.0       Good    True      1421.0     4591.0           3.7
# 18  16.0   512.0       Good    True      1740.0     5479.0           3.7
# 19  16.0   500.0  Very Good    True      1766.0     4873.0           3.2
# 20  16.0   256.0  Very Good    True       914.0     2545.0           4.0
# 21  16.0   500.0       Good    True       949.0     2620.0           2.5
#
#     GB6 Multi/€
# 0          10.7
# 1           8.7
# 2          12.7
# 3          11.7
# 4          11.3
# 5          10.2
# 6          10.5
# 7           9.9
# 8           8.8
# 9           9.6
# 10          9.7
# 11          9.6
# 12          8.6
# 13          7.5
# 14          7.2
# 15          6.6
# 16          9.0
# 17         12.1
# 18         11.7
# 19          8.9
# 20         11.1
# 21          6.9

# %% [markdown]
# ## CPUs table

# %%
row_count, cpus_raw = get_baserow_rows(CPUS_TABLE, BASEROW_ACCESS_TOKEN)
print(f'CPUs table has {row_count} rows')
# print first row
cpus_raw[0]
# Out:
# CPUs table has 17 rows
# {'id': 68,
#  'order': '0.50000000000000000000',
#  'Name': 'Intel Core i5-6200U',
#  'Geekbench 6 Single-Core': '916',
#  'Geekbench 6 Multi-Core': '1832',
#  'Architecture': [{'id': 1,
#    'value': 'Skylake',
#    'order': '1.00000000000000000000'}],
#  'Launch date': '2015-07-01',
#  'Product URL': 'https://www.intel.com/content/www/us/en/products/sku/88193/intel-core-i56200u-processor-3m-cache-up-to-2-80-ghz/specifications.html',
#  'Comment': '',
#  'Cores': '2',
#  'P Cores': None,
#  'Notebook offers': [{'id': 71,
#    'value': 'Latitude 5480 240 GB Good',
#    'order': '0.66666666666666662966'}],
#  'NotebookCheck': '',
#  'Geekbench 5.5 Single-Core': None,
#  'Geekbench 5.5 Multi-Core': None,
#  'Age': '9.7',
#  'GB6 Source': {'id': 2776699, 'value': 'MyQ50', 'color': 'darker-pink'},
#  'GB5 Source': None,
#  'Designer': [{'id': 1, 'value': 'Intel'}],
#  'Win11 Compatible': False,
#  'Notebook series': [{'ids': {'database_table_444311': 71,
#     'database_table_444404': 70},
#    'value': 'Latitude 5480'}]}

# %%
def simplify_cpus(table_raw):
    """simplifies the raw notebook offers JSON"""
    table_simple = []
    for row in table_raw:
        row_simple = {
            'Name': row['Name'],
            'Launch date': row['Launch date'],
            'Cores': row['Cores'],
            'Age': row['Age'],
            'Architecture': row['Architecture'][0]['value'],
            'GB6 Single': float(row['Geekbench 6 Single-Core']),
            'GB6 Multi': float(row['Geekbench 6 Multi-Core']),
            'Designer': row['Designer'][0]['value'],
            'Win11': 'Yes' if row['Win11 Compatible'] else 'No',
            
        }
        table_simple.append(row_simple)
    nrow = len(table_simple)
    print(f'{nrow} cpus simplified')
    return table_simple

# %%
cpus = simplify_cpus(cpus_raw)
cpus_df = pd.DataFrame.from_dict(cpus)
#cpus_df['Launch date'] = pd.to_datetime(cpus_df['Launch date']) # date string to datetime. useless to make a CSV
cpus_df
# Out:
# 17 cpus simplified
#                      Name Launch date Cores  Age  Architecture  GB6 Single  \
# 0     Intel Core i5-6200U  2015-07-01     2  9.7       Skylake       916.0
# 1     Intel Core i5-6300U  2015-07-01     2  9.7       Skylake       965.0
# 2     Intel Core i5-7300U  2017-01-01     2  8.1     Kaby Lake      1088.0
# 3     Intel Core i5-8250U  2017-07-01     4  7.6   Kaby Lake R      1145.0
# 4     Intel Core i5-8350U  2017-07-01     4  7.6   Kaby Lake R      1191.0
# 5     Intel Core i5-8365U  2019-04-01     4  5.9  Whiskey Lake      1270.0
# 6     Intel Core i5-9400H  2019-04-01     4  5.9   Coffee Lake      1429.0
# 7    Intel Core i5-10210U  2019-07-01     4  5.7    Comet Lake      1229.0
# 8    Intel Core i5-10310U  2020-04-01     4  4.9    Comet Lake      1297.0
# 9    Intel Core i5-1135G7  2020-07-01     4  4.6    Tiger Lake      1702.0
# 10   Intel Core i5-1145G7  2021-01-01     4  4.1    Tiger Lake      1766.0
# 11    Intel Core i5-1245U  2022-01-01    10  3.1    Alder Lake      1964.0
# 12    Intel Core i5-1335U  2023-01-01    10  2.1   Raptor Lake      2103.0
# 13  AMD Ryzen 7 PRO 2700U  2017-10-01     4  7.4   Raven Ridge       914.0
# 14  AMD Ryzen 5 PRO 3500U  2019-01-01     4  6.1       Picasso       949.0
# 15  AMD Ryzen 5 PRO 4650U  2020-07-01     6  4.6        Renoir      1421.0
# 16  AMD Ryzen 5 PRO 5650U  2021-03-01     6  4.0       Cezanne      1740.0
#
#     GB6 Multi Designer Win11
# 0      1832.0    Intel    No
# 1      1910.0    Intel    No
# 2      2030.0    Intel    No
# 3      3126.0    Intel   Yes
# 4      3237.0    Intel   Yes
# 5      3167.0    Intel   Yes
# 6      4347.0    Intel   Yes
# 7      3088.0    Intel   Yes
# 8      3450.0    Intel   Yes
# 9      4694.0    Intel   Yes
# 10     4873.0    Intel   Yes
# 11     6269.0    Intel   Yes
# 12     6786.0    Intel   Yes
# 13     2545.0      AMD    No
# 14     2620.0      AMD   Yes
# 15     4591.0      AMD   Yes
# 16     5479.0      AMD   Yes

# %%
cpus_df.to_csv('CPUs.csv', index=False)
