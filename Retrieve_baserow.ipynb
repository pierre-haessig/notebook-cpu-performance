# %% [markdown]
# # Retrieve notebook and CPU tables from Baserow
#
# PH, Feb 2025

# %%
import requests
import pandas as pd

# %% [markdown]
# Baserow API access token (read only access to all tables of the *Computers* project

# %%
BASEROW_ACCESS_TOKEN='3dDIsaSBqeszii1EmBJ5FSKVPSJmDms8'

# %% [markdown]
# Table IDs

# %%
NB_OFFERS_TABLE = '444311'
CPUS_TABLE = '444310'

# %%
def get_baserow_rows(TABLE_ID, TOKEN, page=1, size=100):
    """Read rows of table `TABLE_ID`.
    
    Returns (row count, json 'results' field)

    If API error, returns the json error message.
    """
    params = {
        'page': int(page),
        'size': int(size),
    }
    res = requests.get(
        f'https://api.baserow.io/api/database/rows/table/{TABLE_ID}/?user_field_names=true',
        headers={
            'Authorization': f'Token {TOKEN}'
        },
        params = params
    )
    if res.ok:
        json = res.json()
        row_count = json['count']
        results = json['results']
        if len(results) < row_count:
            print(f'Warning: response got paginated ({len(results)} rows retrieved over a total of {row_count}).')
        return row_count, results
    else:
        print(f'Warning: unsuccessul request (code {res.status_code})!')
        return 0, res.json()

# %% [markdown]
# ## Notebook offers table

# %%
row_count, nb_offers_raw = get_baserow_rows(NB_OFFERS_TABLE, BASEROW_ACCESS_TOKEN)
print(f'Notebook offers table has {row_count} rows')
# print first row
nb_offers_raw[0]
# Out:
# Notebook offers table has 30 rows
# {'id': 70,
#  'order': '0.50000000000000000000',
#  'Offer': 'T470S 256GB Good',
#  'Active': True,
#  'CPU': [{'id': 67,
#    'value': 'Intel Core i5-7300U',
#    'order': '1.33333333333333325932'}],
#  'Condition': {'id': 2750619, 'value': 'Good', 'color': 'darker-blue'},
#  'RAM': '16',
#  'SSD': '256',
#  'Date de création': '2025-02-22',
#  'ITJustGood': 'https://www.itjustgood.com/ultrabook-lenovo-thinkpad-t470s-reconditionne-intel-core-i5-7200u-16go-ddr4-256go-ssd-nvme-thunderbolt-3-windows-10-14-full-hd-tactile-0btd8993.html',
#  'Price': '190',
#  'Screen resolution': {'id': 2750658, 'value': '1920x1080', 'color': 'green'},
#  'Thunderbolt': False,
#  'Series': [{'id': 69,
#    'value': 'ThinkPad T470S',
#    'order': '3.50000000000000000000'}],
#  'CPU Age': [{'id': 67, 'value': '8.2'}],
#  'GB6 Single': [{'id': 67, 'value': '1088'}],
#  'GB6 Multi': [{'id': 67, 'value': '2030'}],
#  'GB6 Single/€': [{'id': 67, 'value': '5.7'}],
#  'GB6 Multi/€': [{'id': 67, 'value': '10.7'}],
#  'Designer': [{'id': 69, 'value': 'Lenovo'}]}

# %%
def simplify_nb_offers(table_raw):
    """simplifies the raw notebook offers JSON"""
    table_simple = []
    for row in table_raw:
        row_simple = {
            'Offer': row['Offer'],
            'Price': float(row['Price']),
            'Designer': row['Designer'][0]['value'],
            'Series': row['Series'][0]['value'],
            'CPU': row['CPU'][0]['value'],
            'CPU Age': float(row['CPU Age'][0]['value']),
            'RAM': float(row['RAM']),
            'SSD': float(row['SSD']),
            'Screen resolution': row['Screen resolution']['value'],
            'Condition': row['Condition']['value'],
            'Active': row['Active'],
            'GB6 Single': float(row['GB6 Single'][0]['value']),
            'GB6 Multi': float(row['GB6 Multi'][0]['value']),
            'GB6 Single/€': float(row['GB6 Single/€'][0]['value']),
            'GB6 Multi/€': float(row['GB6 Multi/€'][0]['value']),
            'ITJustGood': row['ITJustGood'],
        }
        table_simple.append(row_simple)
    nrow = len(table_simple)
    print(f'{nrow} notebook offers simplified')
    return table_simple

# %%
nb_offers = simplify_nb_offers(nb_offers_raw)
offers_df = pd.DataFrame.from_dict(nb_offers)
offers_df
# Out:
# 30 notebook offers simplified
#                                 Offer  Price Designer               Series  \
# 0                    T470S 256GB Good  190.0   Lenovo       ThinkPad T470S
# 1           Latitude 5480 240 GB Good  210.0     Dell        Latitude 5480
# 2                  Dell Latitude 5400  250.0     Dell        Latitude 5400
# 3                  Dell Latitude 5400  270.0     Dell        Latitude 5400
# 4                  Dell Latitude 3400  280.0     Dell        Latitude 3400
# 5           Latitude 5410 240GB VGood  400.0     Dell        Latitude 5410
# 6               Lenovo ThinkPad T490S  310.0   Lenovo       ThinkPad T490S
# 7                   T495S 500GB VGood  350.0   Lenovo       ThinkPad T495S
# 8                  Dell Latitude 5410  330.0     Dell        Latitude 5410
# 9            Latitude 5410 240GB Good  300.0     Dell        Latitude 5410
# 10              Lenovo ThinkPad T490S  360.0   Lenovo       ThinkPad T490S
# 11  Latitude 5420 10th-gen 500GB Good  360.0     Dell        Latitude 5420
# 12                 Dell Latitude 5420  500.0     Dell        Latitude 5420
# 13       EliteBook 640 G9 512GB VGood  650.0       HP     EliteBook 640 G9
# 14                   T14 G3 1TB VGood  730.0   Lenovo  ThinkPad T14S Gen 3
# 15          Latitude 5420 240GB VGood  470.0     Dell        Latitude 5420
# 16                    T14 G1 512 Good  410.0   Lenovo  ThinkPad T14S Gen 1
# 17                   T14 G1 256 VGood  430.0   Lenovo  ThinkPad T14S Gen 1
# 18          Latitude 5420 500GB VGood  600.0     Dell        Latitude 5420
# 19                   T14 G1 512 VGood  470.0   Lenovo  ThinkPad T14S Gen 1
# 20               T14 G1 AMD 240G Good  510.0   Lenovo  ThinkPad T14S Gen 1
# 21              T14 G1 AMD 512GB Good  380.0   Lenovo  ThinkPad T14S Gen 1
# 22        EliteBook 845 G8 512GB Good  470.0       HP     EliteBook 845 G8
# 23         ProBook 640 G8 500GB VGood  550.0       HP       ProBook 640 G8
# 24   EliteBook 745 G5 AMD 256GB VGood  230.0       HP     EliteBook 745 G5
# 25                   T495S 500GB Good  310.0   Lenovo       ThinkPad T495S
# 26             T14 G1 AMD 512GB VGood  400.0   Lenovo  ThinkPad T14S Gen 1
# 27                    T495 500GB Good  380.0   Lenovo        ThinkPad T495
# 28       EliteBook 640 G9 500GB VGood  560.0       HP     EliteBook 640 G9
# 29           Latitude 5420 500GB Good  400.0     Dell        Latitude 5420
#
#                       CPU  CPU Age   RAM     SSD Screen resolution  Condition  \
# 0     Intel Core i5-7300U      8.2  16.0   256.0         1920x1080       Good
# 1     Intel Core i5-6200U      9.7  16.0   240.0         1920x1080       Good
# 2     Intel Core i5-8365U      6.0  16.0   240.0         1920x1080       Good
# 3     Intel Core i5-8365U      6.0  16.0   240.0          1366x768  Very Good
# 4     Intel Core i5-8365U      6.0  16.0   240.0         1920x1080  Very Good
# 5    Intel Core i5-10310U      5.0  16.0   240.0         1920x1080  Very Good
# 6     Intel Core i5-8365U      6.0  16.0   500.0         1920x1080       Good
# 7   AMD Ryzen 5 PRO 3500U      6.2  16.0   500.0         1920x1080  Very Good
# 8    Intel Core i5-10310U      5.0  16.0   240.0          1366x768       Good
# 9    Intel Core i5-10310U      5.0  16.0   240.0         1920x1080       Good
# 10    Intel Core i5-8365U      6.0  16.0   500.0         1920x1080  Very Good
# 11   Intel Core i5-10310U      5.0  16.0   500.0         1920x1080       Good
# 12   Intel Core i5-1145G7      4.2  16.0   500.0          1366x768  Very Good
# 13    Intel Core i5-1245U      3.2  16.0   500.0         1920x1080  Very Good
# 14    Intel Core i5-1245U      3.2  16.0  1000.0         1920x1080  Very Good
# 15   Intel Core i5-1145G7      4.2  16.0   240.0         1920x1080  Very Good
# 16   Intel Core i5-10210U      5.7  16.0   512.0         1920x1080       Good
# 17   Intel Core i5-10210U      5.7  16.0   256.0         1920x1080  Very Good
# 18   Intel Core i5-1145G7      4.2  16.0   500.0         1920x1080  Very Good
# 19   Intel Core i5-10210U      5.7  16.0   512.0         1920x1080  Very Good
# 20  AMD Ryzen 5 PRO 4650U      4.7  16.0   240.0         1920x1080       Good
# 21  AMD Ryzen 5 PRO 4650U      4.7  16.0   512.0         1920x1080       Good
# 22  AMD Ryzen 5 PRO 5650U      4.0  16.0   512.0         1920x1080       Good
# 23   Intel Core i5-1145G7      4.2  16.0   500.0         1920x1080  Very Good
# 24  AMD Ryzen 7 PRO 2700U      7.5  16.0   256.0         1920x1080  Very Good
# 25  AMD Ryzen 5 PRO 3500U      6.2  16.0   500.0         1920x1080       Good
# 26  AMD Ryzen 5 PRO 4650U      4.7  16.0   512.0         1920x1080  Very Good
# 27  AMD Ryzen 5 PRO 3500U      6.2  16.0   500.0         1920x1080       Good
# 28    Intel Core i5-1245U      3.2  16.0   512.0         1920x1080  Very Good
# 29   Intel Core i5-1145G7      4.2  16.0   500.0         1920x1080       Good
#
#     Active  GB6 Single  GB6 Multi  GB6 Single/€  GB6 Multi/€  \
# 0     True      1088.0     2030.0           5.7         10.7
# 1     True       916.0     1832.0           4.4          8.7
# 2     True      1270.0     3167.0           5.1         12.7
# 3     True      1270.0     3167.0           4.7         11.7
# 4     True      1270.0     3167.0           4.5         11.3
# 5     True      1297.0     3450.0           3.2          8.6
# 6     True      1270.0     3167.0           4.1         10.2
# 7     True       949.0     2620.0           2.7          7.5
# 8     True      1297.0     3450.0           3.9         10.5
# 9     True      1297.0     3450.0           4.3         11.5
# 10    True      1270.0     3167.0           3.5          8.8
# 11    True      1297.0     3450.0           3.6          9.6
# 12    True      1766.0     4873.0           3.5          9.7
# 13   False      1964.0     6269.0           3.0          9.6
# 14   False      1964.0     6269.0           2.7          8.6
# 15    True      1766.0     4873.0           3.8         10.4
# 16    True      1229.0     3088.0           3.0          7.5
# 17    True      1229.0     3088.0           2.9          7.2
# 18    True      1766.0     4873.0           2.9          8.1
# 19    True      1229.0     3088.0           2.6          6.6
# 20   False      1421.0     4591.0           2.8          9.0
# 21    True      1421.0     4591.0           3.7         12.1
# 22    True      1740.0     5479.0           3.7         11.7
# 23    True      1766.0     4873.0           3.2          8.9
# 24    True       914.0     2545.0           4.0         11.1
# 25    True       949.0     2620.0           3.1          8.5
# 26    True      1421.0     4591.0           3.6         11.5
# 27   False       949.0     2620.0           2.5          6.9
# 28   False      1964.0     6269.0           3.5         11.2
# 29    True      1766.0     4873.0           4.4         12.2
#
#                                            ITJustGood
# 0   https://www.itjustgood.com/ultrabook-lenovo-th...
# 1   https://www.itjustgood.com/ordinateur-portable...
# 2   https://www.itjustgood.com/ordinateur-portable...
# 3   https://www.itjustgood.com/pc-portable-recondi...
# 4   https://www.itjustgood.com/ultrabook-reconditi...
# 5   https://www.itjustgood.com/ordinateur-portable...
# 6   https://www.itjustgood.com/ultrabook-lenovo-th...
# 7   https://www.itjustgood.com/ultrabook-reconditi...
# 8   https://www.itjustgood.com/ordinateur-portable...
# 9   https://www.itjustgood.com/ordinateur-portable...
# 10  https://www.itjustgood.com/ultrabook-lenovo-th...
# 11  https://www.itjustgood.com/ordinateur-portable...
# 12  https://www.itjustgood.com/ordinateur-portable...
# 13  https://www.itjustgood.com/ultrabook-reconditi...
# 14  https://www.itjustgood.com/ultrabook-reconditi...
# 15  https://www.itjustgood.com/ordinateur-portable...
# 16  https://www.itjustgood.com/ultrabook-reconditi...
# 17  https://www.itjustgood.com/ultrabook-reconditi...
# 18  https://www.itjustgood.com/ordinateur-portable...
# 19  https://www.itjustgood.com/ultrabook-reconditi...
# 20  https://www.itjustgood.com/ultrabook-reconditi...
# 21  https://www.itjustgood.com/ultrabook-reconditi...
# 22  https://www.itjustgood.com/ultrabook-reconditi...
# 23  https://www.itjustgood.com/ultrabook-reconditi...
# 24  https://www.itjustgood.com/pc-portable-recondi...
# 25  https://www.itjustgood.com/ultrabook-reconditi...
# 26  https://www.itjustgood.com/ultrabook-reconditi...
# 27  https://www.itjustgood.com/ultrabook-lenovo-th...
# 28  https://www.itjustgood.com/ultrabook-reconditi...
# 29  https://www.itjustgood.com/ordinateur-portable...

# %%
offers_df.to_csv('Offers.csv', index=False)

# %% [markdown]
# ## CPUs table

# %%
row_count, cpus_raw = get_baserow_rows(CPUS_TABLE, BASEROW_ACCESS_TOKEN)
print(f'CPUs table has {row_count} rows')
# print first row
cpus_raw[0]
# Out:
# CPUs table has 31 rows
# {'id': 133,
#  'order': '0.33333333333333331483',
#  'Name': 'Intel Core i5-5200U',
#  'Geekbench 6 Single-Core': '854',
#  'Geekbench 6 Multi-Core': '1611',
#  'Architecture': [{'id': 100,
#    'value': 'Broadwell',
#    'order': '0.50000000000000000000'}],
#  'Launch date': '2015-01-01',
#  'Product URL': 'https://www.intel.com/content/www/us/en/products/sku/85212/intel-core-i55200u-processor-3m-cache-up-to-2-70-ghz/specifications.html',
#  'Comment': '',
#  'Cores': '2',
#  'P Cores': None,
#  'Notebook offers': [],
#  'NotebookCheck': '',
#  'Geekbench 5.5 Single-Core': None,
#  'Geekbench 5.5 Multi-Core': None,
#  'Age': '10.2',
#  'GB5 Source': None,
#  'Designer': [{'id': 100, 'value': 'Intel'}],
#  'Win11 Compatible': False,
#  'Notebook series': []}

# %%
def simplify_cpus(table_raw):
    """simplifies the raw notebook offers JSON"""
    table_simple = []
    for row in table_raw:
        row_simple = {
            'Name': row['Name'],
            'Designer': row['Designer'][0]['value'],
            'Launch date': row['Launch date'],
            'Cores': row['Cores'],
            'Launch date': row['Launch date'],
            'Age': row['Age'],
            'Architecture': row['Architecture'][0]['value'],
            'GB6 Single': float(row['Geekbench 6 Single-Core']),
            'GB6 Multi': float(row['Geekbench 6 Multi-Core']),
            'Win11': 'Yes' if row['Win11 Compatible'] else 'No',
            'Product URL': row['Product URL']
            
        }
        table_simple.append(row_simple)
    nrow = len(table_simple)
    print(f'{nrow} cpus simplified')
    return table_simple

# %%
cpus = simplify_cpus(cpus_raw)
cpus_df = pd.DataFrame.from_dict(cpus)
#cpus_df['Launch date'] = pd.to_datetime(cpus_df['Launch date']) # date string to datetime. useless to make a CSV
cpus_df
# Out:
# 31 cpus simplified
#                        Name Designer Launch date Cores   Age  Architecture  \
# 0       Intel Core i5-5200U    Intel  2015-01-01     2  10.2     Broadwell
# 1       Intel Core i5-5300U    Intel  2015-01-01     2  10.2     Broadwell
# 2       Intel Core i5-6200U    Intel  2015-07-01     2   9.7       Skylake
# 3       Intel Core i5-6300U    Intel  2015-07-01     2   9.7       Skylake
# 4       Intel Core i5-7200U    Intel  2016-10-01     2   8.5     Kaby Lake
# 5       Intel Core i5-7300U    Intel  2017-01-01     2   8.2     Kaby Lake
# 6       Intel Core i5-8250U    Intel  2017-07-01     4   7.7   Kaby Lake R
# 7       Intel Core i5-8350U    Intel  2017-07-01     4   7.7   Kaby Lake R
# 8       Intel Core i5-8365U    Intel  2019-04-01     4   6.0  Whiskey Lake
# 9       Intel Core i5-9400H    Intel  2019-04-01     4   6.0   Coffee Lake
# 10     Intel Core i5-10210U    Intel  2019-07-01     4   5.7    Comet Lake
# 11     Intel Core i5-10310U    Intel  2020-04-01     4   5.0    Comet Lake
# 12     Intel Core i5-1035G4    Intel  2019-10-01     4   5.5      Ice Lake
# 13     Intel Core i5-1035G7    Intel  2019-10-01     4   5.5      Ice Lake
# 14     Intel Core i5-1135G7    Intel  2020-07-01     4   4.7    Tiger Lake
# 15     Intel Core i5-1145G7    Intel  2021-01-01     4   4.2    Tiger Lake
# 16      Intel Core i5-1235U    Intel  2022-01-01    10   3.2    Alder Lake
# 17      Intel Core i5-1245U    Intel  2022-01-01    10   3.2    Alder Lake
# 18      Intel Core i5-1335U    Intel  2023-01-01    10   2.2   Raptor Lake
# 19      Intel Core i5-1345U    Intel  2023-01-01    10   2.2   Raptor Lake
# 20  Intel Core Ultra 5 125U    Intel  2023-10-01    12   1.5    Metor Lake
# 21  Intel Core Ultra 5 135U    Intel  2023-10-01    12   1.5    Metor Lake
# 22  Intel Core Ultra 5 125H    Intel  2023-10-01    14   1.5    Metor Lake
# 23  Intel Core Ultra 5 135H    Intel  2023-10-01    14   1.5    Metor Lake
# 24    AMD Ryzen 7 PRO 2700U      AMD  2017-10-01     4   7.5   Raven Ridge
# 25    AMD Ryzen 5 PRO 3500U      AMD  2019-01-01     4   6.2       Picasso
# 26    AMD Ryzen 5 PRO 4650U      AMD  2020-07-01     6   4.7        Renoir
# 27    AMD Ryzen 5 PRO 5650U      AMD  2021-03-01     6   4.1       Cezanne
# 28    AMD Ryzen 5 PRO 6650U      AMD  2022-04-19     6   2.9     Rembrandt
# 29    AMD Ryzen 5 PRO 7540U      AMD  2023-03-05     6   2.1       Phoenix
# 30    AMD Ryzen 5 PRO 8540U      AMD  2024-04-01     6   1.0    Hawk Point
#
#     GB6 Single  GB6 Multi Win11  \
# 0        854.0     1611.0    No
# 1        908.0     1692.0    No
# 2        916.0     1832.0    No
# 3        965.0     1910.0    No
# 4       1009.0     1987.0    No
# 5       1088.0     2030.0    No
# 6       1145.0     3126.0   Yes
# 7       1191.0     3237.0   Yes
# 8       1270.0     3167.0   Yes
# 9       1429.0     4347.0   Yes
# 10      1229.0     3088.0   Yes
# 11      1297.0     3450.0   Yes
# 12      1435.0     3742.0   Yes
# 13      1419.0     3791.0   Yes
# 14      1702.0     4694.0   Yes
# 15      1766.0     4873.0   Yes
# 16      1950.0     5846.0   Yes
# 17      1964.0     6269.0   Yes
# 18      2103.0     6786.0   Yes
# 19      2202.0     6967.0   Yes
# 20      2072.0     8107.0   Yes
# 21      2132.0     8667.0   Yes
# 22      2123.0     9320.0   Yes
# 23      2207.0     9885.0   Yes
# 24       914.0     2545.0   Yes
# 25       949.0     2620.0   Yes
# 26      1421.0     4590.0   Yes
# 27      1740.0     5479.0   Yes
# 28      1828.0     6717.0   Yes
# 29      2226.0     8076.0   Yes
# 30      2345.0     8081.0   Yes
#
#                                           Product URL
# 0   https://www.intel.com/content/www/us/en/produc...
# 1   https://www.intel.com/content/www/us/en/produc...
# 2   https://www.intel.com/content/www/us/en/produc...
# 3   https://www.intel.com/content/www/us/en/produc...
# 4   https://www.intel.com/content/www/us/en/produc...
# 5   https://www.intel.com/content/www/us/en/produc...
# 6   https://www.intel.com/content/www/us/en/produc...
# 7   https://www.intel.com/content/www/us/en/produc...
# 8   https://www.intel.com/content/www/us/en/produc...
# 9   https://www.intel.com/content/www/us/en/produc...
# 10  https://www.intel.com/content/www/us/en/produc...
# 11  https://www.intel.com/content/www/us/en/produc...
# 12  https://www.intel.com/content/www/us/en/produc...
# 13  https://www.intel.com/content/www/us/en/produc...
# 14  https://www.intel.com/content/www/us/en/produc...
# 15  https://www.intel.com/content/www/us/en/produc...
# 16  https://www.intel.com/content/www/us/en/produc...
# 17  https://www.intel.com/content/www/us/en/produc...
# 18  https://www.intel.com/content/www/us/en/produc...
# 19  https://www.intel.com/content/www/us/en/produc...
# 20  https://www.intel.com/content/www/us/en/produc...
# 21  https://www.intel.com/content/www/us/en/produc...
# 22  https://www.intel.com/content/www/us/en/produc...
# 23  https://www.intel.com/content/www/us/en/produc...
# 24  https://www.amd.com/en/support/downloads/drive...
# 25  https://www.amd.com/en/support/downloads/drive...
# 26  https://www.amd.com/en/support/downloads/drive...
# 27  https://www.amd.com/en/support/downloads/drive...
# 28  https://www.amd.com/en/support/downloads/drive...
# 29  https://www.amd.com/en/products/processors/lap...
# 30  https://www.amd.com/en/products/processors/lap...

# %%
cpus_df.to_csv('CPUs.csv', index=False)
